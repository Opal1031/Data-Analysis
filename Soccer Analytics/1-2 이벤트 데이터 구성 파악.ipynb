# %% [markdown]
# ### 강의에서 사용된 파이썬 주요 기능

# %% [markdown]
# - 데이터 불러오기
#   - pandas.read_csv: https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html
#   - pandas.read_pickle: https://pandas.pydata.org/docs/reference/api/pandas.read_pickle.html

# %% [markdown]
# - 중복 제거를 활용한 데이터 구성 파악
#   - pandas.Series.unique: https://pandas.pydata.org/docs/reference/api/pandas.Series.unique.html
#   - pandas.DataFrame.drop_duplicates: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.drop_duplicates.html
#   - pandas.DataFrame.sort_values: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.sort_values.html
#   - set: https://wikidocs.net/22262

# %% [markdown]
# ### 데이터 불러오기

# %%
import pandas as pd

# %% [markdown]
# ##### (1) 경기 정보 불러오기

# %%
dataset_name = 'World_Cup'
match_df = pd.read_csv(f'data/refined_events/{dataset_name}/matches.csv', index_col=0, encoding='utf-8-sig')
match_df
# Out:
#           gameweek             datetime                         venue  \
# match_id
# 2057954          1  2018-06-14 15:00:00  Olimpiyskiy stadion Luzhniki
# 2057955          1  2018-06-15 12:00:00           Stadion Central'nyj
# 2057961          1  2018-06-15 15:00:00           Stadion Krestovskyi
# 2057960          1  2018-06-15 18:00:00     Olimpiyskiy Stadion Fisht
# 2057966          1  2018-06-16 10:00:00                  Kazan' Arena
# ...            ...                  ...                           ...
# 2058012          0  2018-07-07 18:00:00     Olimpiyskiy Stadion Fisht
# 2058014          0  2018-07-10 18:00:00           Stadion Krestovskyi
# 2058015          0  2018-07-11 18:00:00  Olimpiyskiy stadion Luzhniki
# 2058016          0  2018-07-14 14:00:00           Stadion Krestovskyi
# 2058017          0  2018-07-15 15:00:00  Olimpiyskiy stadion Luzhniki
#
#           team1_id team1_name  team1_goals  team2_id    team2_name  \
# match_id
# 2057954      14358     Russia            5     16521  Saudi Arabia
# 2057955      16129      Egypt            0     15670       Uruguay
# 2057961      16216    Morocco            0     10840          Iran
# 2057960       9905   Portugal            3      1598         Spain
# 2057966       4418     France            2      8493     Australia
# ...            ...        ...          ...       ...           ...
# 2058012      14358     Russia            2      9598       Croatia
# 2058014       4418     France            1      5629       Belgium
# 2058015       9598    Croatia            2      2413       England
# 2058016       5629    Belgium            2      2413       England
# 2058017       4418     France            4      9598       Croatia
#
#           team2_goals   duration
# match_id
# 2057954             0    Regular
# 2057955             1    Regular
# 2057961             1    Regular
# 2057960             3    Regular
# 2057966             1    Regular
# ...               ...        ...
# 2058012             2  Penalties
# 2058014             0    Regular
# 2058015             1  ExtraTime
# 2058016             0    Regular
# 2058017             2    Regular
#
# [64 rows x 10 columns]

# %% [markdown]
# ##### (2) 경기 정보 필터링

# %%
match_df[(match_df['team1_name'] == 'Korea Republic') | (match_df['team2_name'] == 'Korea Republic')]
# Out:
#           gameweek             datetime                    venue  team1_id  \
# match_id
# 2057985          1  2018-06-18 12:00:00  Stadion Nizhny Novgorod      7047
# 2057987          2  2018-06-23 15:00:00             Rostov Arena     14855
# 2057988          3  2018-06-27 14:00:00             Kazan' Arena     14855
#
#               team1_name  team1_goals  team2_id      team2_name  team2_goals  \
# match_id
# 2057985           Sweden            1     14855  Korea Republic            0
# 2057987   Korea Republic            1     15473          Mexico            2
# 2057988   Korea Republic            2      3148         Germany            0
#
#          duration
# match_id
# 2057985   Regular
# 2057987   Regular
# 2057988   Regular

# %% [markdown]
# ##### (3) 경기 이벤트 데이터 불러오기

# %% [markdown]
# - 3차전 한국 vs 독일 이벤트 데이터를 DataFrame 형태로 불러오기

# %%
match_id = 2057988
match_events = pd.read_pickle(f'data/refined_events/{dataset_name}/{match_id}.pkl')
match_events
# Out:
#      match_id   event_id period      time team_id       team_name player_id  \
# 0     2057988  260662125     1H     1.157    3148         Germany      3319
# 1     2057988  260662126     1H     2.669    3148         Germany     14723
# 2     2057988  260662127     1H     4.965    3148         Germany      3319
# 3     2057988  260662128     1H     8.096    3148         Germany    134383
# 4     2057988  260662129     1H     9.505    3148         Germany     14723
# ...       ...        ...    ...       ...     ...             ...       ...
# 1659  2057988  260664023     2H  3213.652    3148         Germany    134383
# 1660  2057988  260664025     2H  3216.522    3148         Germany     14723
# 1661  2057988  260664027     2H  3218.856    3148         Germany     14732
# 1662  2057988  260664031     2H  3219.998    3148         Germany     14795
# 1663  2057988  260664180     2H  3258.367   14855  Korea Republic    256043
#
#        player_name          event_type sub_event_type  \
# 0          M. Özil                Pass    Simple pass
# 1         T. Kroos                Pass    Simple pass
# 2          M. Özil                Pass    Simple pass
# 3          N. Süle                Pass    Simple pass
# 4         T. Kroos                Pass    Simple pass
# ...            ...                 ...            ...
# 1659       N. Süle  Others on the ball          Touch
# 1660      T. Kroos                Pass    Simple pass
# 1661     T. Müller                Pass          Cross
# 1662    M. Hummels                Shot           Shot
# 1663  Hyun-Woo Cho           Free kick      Goal kick
#
#                                                    tags  start_x  start_y  \
# 0                                            [Accurate]    52.00    34.68
# 1                                            [Accurate]    39.52    36.04
# 2                                            [Accurate]    46.80    32.64
# 3                                            [Accurate]    32.24    25.84
# 4                                            [Accurate]    38.48    32.64
# ...                                                 ...      ...      ...
# 1659                                                 []    85.28    31.96
# 1660                                         [Accurate]    72.80    40.12
# 1661             [Key pass, Right foot, High, Accurate]    90.48    51.68
# 1662  [Head/body, Opportunity, Position: Out high le...    96.72    36.72
# 1663                                                 []     0.00    34.00
#
#        end_x  end_y
# 0      39.52  36.04
# 1      46.80  32.64
# 2      32.24  25.84
# 3      38.48  32.64
# 4      27.04  24.48
# ...      ...    ...
# 1659   72.80  40.12
# 1660   90.48  51.68
# 1661   96.72  36.72
# 1662  104.00  34.00
# 1663     NaN    NaN
#
# [1664 rows x 15 columns]

# %% [markdown]
# ### 이벤트 데이터 인덱싱(indexing), 슬라이싱(slicing), 필터링(filtering)

# %% [markdown]
# ##### (1) 열 인덱싱(column indexing)

# %%
match_events['player_name']
# Out:
# 0            M. Özil
# 1           T. Kroos
# 2            M. Özil
# 3            N. Süle
# 4           T. Kroos
#             ...
# 1659         N. Süle
# 1660        T. Kroos
# 1661       T. Müller
# 1662      M. Hummels
# 1663    Hyun-Woo Cho
# Name: player_name, Length: 1664, dtype: object

# %% [markdown]
# ##### (2) 행 인덱싱(row indexing)

# %%
match_events.loc[0]
# Out:
# match_id              2057988
# event_id            260662125
# period                     1H
# time                    1.157
# team_id                  3148
# team_name             Germany
# player_id                3319
# player_name           M. Özil
# event_type               Pass
# sub_event_type    Simple pass
# tags               [Accurate]
# start_x                  52.0
# start_y                 34.68
# end_x                   39.52
# end_y                   36.04
# Name: 0, dtype: object

# %% [markdown]
# ##### (3) 슬라이싱

# %%
match_events[0:10]
# Out:
#   match_id   event_id period    time team_id team_name player_id player_name  \
# 0  2057988  260662125     1H   1.157    3148   Germany      3319     M. Özil
# 1  2057988  260662126     1H   2.669    3148   Germany     14723    T. Kroos
# 2  2057988  260662127     1H   4.965    3148   Germany      3319     M. Özil
# 3  2057988  260662128     1H   8.096    3148   Germany    134383     N. Süle
# 4  2057988  260662129     1H   9.505    3148   Germany     14723    T. Kroos
# 5  2057988  260662130     1H  11.939    3148   Germany    134383     N. Süle
# 6  2057988  260662132     1H  16.057    3148   Germany     14712    M. Neuer
# 7  2057988  260662133     1H  17.709    3148   Germany     14723    T. Kroos
# 8  2057988  260662134     1H  19.595    3148   Germany      3318  S. Khedira
# 9  2057988  260662135     1H  24.925    3148   Germany     14795  M. Hummels
#
#   event_type sub_event_type        tags  start_x  start_y  end_x  end_y
# 0       Pass    Simple pass  [Accurate]    52.00    34.68  39.52  36.04
# 1       Pass    Simple pass  [Accurate]    39.52    36.04  46.80  32.64
# 2       Pass    Simple pass  [Accurate]    46.80    32.64  32.24  25.84
# 3       Pass    Simple pass  [Accurate]    32.24    25.84  38.48  32.64
# 4       Pass    Simple pass  [Accurate]    38.48    32.64  27.04  24.48
# 5       Pass    Simple pass  [Accurate]    27.04    24.48   9.36  33.32
# 6       Pass    Simple pass  [Accurate]     9.36    33.32  28.08  35.36
# 7       Pass    Simple pass  [Accurate]    28.08    35.36  31.20  27.88
# 8       Pass    Simple pass  [Accurate]    31.20    27.88  33.28  51.00
# 9       Pass    Simple pass  [Accurate]    33.28    51.00  30.16  43.52

# %% [markdown]
# ##### (4) 필터링 또는 불린 인덱싱(Boolean indexing)

# %%
match_events[match_events['event_type'] == 'Shot'].head()
# Out:
#     match_id   event_id period      time team_id       team_name player_id  \
# 250  2057988  260662420     1H   825.666    3148         Germany      3318
# 296  2057988  260839866     1H  1144.624   14855  Korea Republic    107529
# 402  2057988  260662698     1H  1442.867   14855  Korea Republic     14911
# 522  2057988  260662734     1H  1927.182    3148         Germany     15024
# 642  2057988  260662853     1H  2288.665    3148         Germany    173214
#
#        player_name event_type sub_event_type  \
# 250     S. Khedira       Shot           Shot
# 296       Yong Lee       Shot           Shot
# 402  Son Heung-Min       Shot           Shot
# 522        M. Reus       Shot           Shot
# 642      T. Werner       Shot           Shot
#
#                                                   tags  start_x  start_y  \
# 250  [Head/body, Opportunity, Position: Goal high r...    93.60    32.64
# 296  [Right foot, Position: Out high right, Not acc...    73.84    24.48
# 402  [Right foot, Opportunity, Position: Out high r...    94.64    25.16
# 522                 [Left foot, Blocked, Not accurate]    82.16    33.32
# 642   [Right foot, Blocked, Opportunity, Not accurate]    94.64    22.44
#
#       end_x  end_y
# 250  104.00  34.00
# 296  104.00  34.00
# 402  104.00  34.00
# 522   89.44  34.68
# 642   92.56  21.76

# %%
match_events[match_events['player_name'] == 'Son Heung-Min'].head()
# Out:
#     match_id   event_id period     time team_id       team_name player_id  \
# 33   2057988  260662167     1H   96.836   14855  Korea Republic     14911
# 67   2057988  260662209     1H  182.528   14855  Korea Republic     14911
# 116  2057988  260662264     1H  363.448   14855  Korea Republic     14911
# 118  2057988  260662267     1H  365.364   14855  Korea Republic     14911
# 222  2057988  260662406     1H  733.162   14855  Korea Republic     14911
#
#        player_name event_type          sub_event_type  \
# 33   Son Heung-Min       Duel   Ground attacking duel
# 67   Son Heung-Min       Duel  Ground loose ball duel
# 116  Son Heung-Min       Duel   Ground attacking duel
# 118  Son Heung-Min       Duel  Ground loose ball duel
# 222  Son Heung-Min       Duel  Ground loose ball duel
#
#                                      tags  start_x  start_y  end_x  end_y
# 33     [Anticipation, Lost, Not accurate]    93.60    27.20  93.60  34.00
# 67                   [Lost, Not accurate]    45.76    20.40  57.20  22.44
# 116  [Free space left, Neutral, Accurate]    73.84    22.44  74.88  27.20
# 118                       [Won, Accurate]    74.88    27.20  78.00  31.96
# 222                  [Lost, Not accurate]    72.80    23.12  71.76  19.72

# %% [markdown]
# ### 중복 제거를 활용한 데이터 구성 파악

# %% [markdown]
# ##### (1) Series 원소 중복 제거

# %% [markdown]
# - 전후반 구분

# %%
match_events['period'].unique()
# Out:
# array(['1H', '2H'], dtype=object)

# %% [markdown]
# - 팀 구분

# %%
match_events['team_name'].unique()
# Out:
# array(['Germany', 'Korea Republic'], dtype=object)

# %% [markdown]
# - 경기 출전 선수

# %%
match_events['player_name'].unique()
# Out:
# array(['M. Özil', 'T. Kroos', 'N. Süle', 'M. Neuer', 'S. Khedira',
#        'M. Hummels', 'Seon-Min Moon', 'Ja-Cheol Koo', 'Young-Gwon Kim',
#        'J. Hector', 'Jae-Sung Lee', 'Yong Lee', 'Son Heung-Min',
#        'Woo-Young Jung', 'Young-Sun Yun', 'Chul Hong', 'J. Kimmich',
#        'M. Reus', 'T. Werner', 'Hyun-Woo Cho', 'Hyun-Soo Jang',
#        'L. Goretzka', 'Hwang Hee-Chan', 'M. Gómez', 'T. Müller',
#        'Se-Jong Ju', 'J. Brandt', 'Yo-Han Go'], dtype=object)

# %% [markdown]
# ##### (2) DataFrame 행 중복 제거

# %% [markdown]
# - 팀과 선수의 ID 및 이름

# %%
match_events[['team_id', 'team_name', 'player_id', 'player_name']].drop_duplicates().sort_values('team_id')
# Out:
#      team_id       team_name player_id     player_name
# 0       3148         Germany      3319         M. Özil
# 99      3148         Germany    173214       T. Werner
# 1361    3148         Germany    146583       J. Brandt
# 163     3148         Germany    134387     L. Goretzka
# 23      3148         Germany     18669       J. Hector
# 48      3148         Germany    224593      J. Kimmich
# 1086    3148         Germany     14732       T. Müller
# 1001    3148         Germany     14731        M. Gómez
# 9       3148         Germany     14795      M. Hummels
# 8       3148         Germany      3318      S. Khedira
# 6       3148         Germany     14712        M. Neuer
# 3       3148         Germany    134383         N. Süle
# 1       3148         Germany     14723        T. Kroos
# 56      3148         Germany     15024         M. Reus
# 977    14855  Korea Republic    349687  Hwang Hee-Chan
# 111    14855  Korea Republic    138633   Hyun-Soo Jang
# 110    14855  Korea Republic    256043    Hyun-Woo Cho
# 1207   14855  Korea Republic    209567      Se-Jong Ju
# 37     14855  Korea Republic     95490  Woo-Young Jung
# 39     14855  Korea Republic    107424   Young-Sun Yun
# 33     14855  Korea Republic     14911   Son Heung-Min
# 28     14855  Korea Republic    107529        Yong Lee
# 25     14855  Korea Republic    299121    Jae-Sung Lee
# 22     14855  Korea Republic     95200  Young-Gwon Kim
# 18     14855  Korea Republic     15781    Ja-Cheol Koo
# 15     14855  Korea Republic     51625   Seon-Min Moon
# 41     14855  Korea Republic    107413       Chul Hong
# 1383   14855  Korea Republic    107623       Yo-Han Go

# %% [markdown]
# - 이벤트 유형의 종류

# %%
match_events[['event_type', 'sub_event_type']].drop_duplicates().sort_values(['event_type', 'sub_event_type'])
# Out:
#                    event_type           sub_event_type
# 94                       Duel                 Air duel
# 16                       Duel    Ground attacking duel
# 15                       Duel    Ground defending duel
# 17                       Duel   Ground loose ball duel
# 21                       Foul                     Foul
# 525                      Foul                Hand foul
# 1135                     Foul               Simulation
# 155                      Foul             Violent Foul
# 244                 Free kick                   Corner
# 22                  Free kick                Free kick
# 199                 Free kick          Free kick cross
# 289                 Free kick           Free kick shot
# 44                  Free kick                Goal kick
# 23                  Free kick                 Throw in
# 355   Goalkeeper leaving line  Goalkeeper leaving line
# 1406                  Offside
# 99         Others on the ball             Acceleration
# 27         Others on the ball                Clearance
# 18         Others on the ball                    Touch
# 109                      Pass                    Cross
# 235                      Pass                Hand pass
# 182                      Pass                Head pass
# 41                       Pass                High pass
# 232                      Pass                   Launch
# 0                        Pass              Simple pass
# 32                       Pass               Smart pass
# 653              Save attempt                 Reflexes
# 251              Save attempt             Save attempt
# 250                      Shot                     Shot
# 977              Substitution                Player in
# 978              Substitution               Player out

# %% [markdown]
# ##### (3) List 원소 중복 제거

# %% [markdown]
# - 추가 태그의 종류

# %%
match_events['tags'].sum()
# Out:
# ['Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Free space right',
#  'Won',
#  'Accurate',
#  'Free space left',
#  'Neutral',
#  'Accurate',
#  'Lost',
#  'Not accurate',
#  'Neutral',
#  'Accurate',
#  'Lost',
#  'Not accurate',
#  'Not accurate',
#  'Accurate',
#  'Accurate',
#  'Neutral',
#  'Accurate',
#  'Neutral',
#  'Accurate',
#  'Not accurate',
#  'Accurate',
#  'Free space left',
#  'Lost',
#  'Not accurate',
#  'Free space right',
#  'Won',
#  'Accurate',
#  'Won',
#  'Accurate',
#  'Accurate',
#  'Anticipation',
#  'Lost',
#  'Not accurate',
#  'Anticipated',
#  'Won',
#  'Accurate',
#  'Not accurate',
#  'Accurate',
#  'Neutral',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Not accurate',
#  'Neutral',
#  'Accurate',
#  'Neutral',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Free space left',
#  'Won',
#  'Accurate',
#  'Free space right',
#  'Sliding tackle',
#  'Lost',
#  'Not accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Take on left',
#  'Lost',
#  'Not accurate',
#  'Take on right',
#  'Won',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Sliding tackle',
#  'Neutral',
#  'Accurate',
#  'Neutral',
#  'Accurate',
#  'Lost',
#  'Not accurate',
#  'Won',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Free space left',
#  'Won',
#  'Accurate',
#  'Free space right',
#  'Sliding tackle',
#  'Lost',
#  'Not accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Neutral',
#  'Accurate',
#  'Neutral',
#  'Accurate',
#  'Won',
#  'Accurate',
#  'Lost',
#  'Not accurate',
#  'Not accurate',
#  'Interception',
#  'Accurate',
#  'Lost',
#  'Not accurate',
#  'Won',
#  'Accurate',
#  'Accurate',
#  'Lost',
#  'Not accurate',
#  'Counter attack',
#  'Won',
#  'Accurate',
#  'Counter attack',
#  'Accurate',
#  'Counter attack',
#  'Not accurate',
#  'Neutral',
#  'Accurate',
#  'Not accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Right foot',
#  'High',
#  'Not accurate',
#  'Accurate',
#  'Not accurate',
#  'Accurate',
#  'Dangerous ball lost',
#  'Not accurate',
#  'Accurate',
#  'Free space left',
#  'Neutral',
#  'Accurate',
#  'Free space right',
#  'Neutral',
#  'Accurate',
#  'Won',
#  'Accurate',
#  'Accurate',
#  'Lost',
#  'Not accurate',
#  'Won',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Won',
#  'Accurate',
#  'Lost',
#  'Not accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Neutral',
#  'Accurate',
#  'Neutral',
#  'Accurate',
#  'Through',
#  'Not accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Not accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Not accurate',
#  'Interception',
#  'Accurate',
#  'Accurate',
#  'Sliding tackle',
#  'Lost',
#  'Not accurate',
#  'Won',
#  'Accurate',
#  'Yellow card',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Interception',
#  'Accurate',
#  'Sliding tackle',
#  'Lost',
#  'Not accurate',
#  'Won',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Free space left',
#  'Won',
#  'Accurate',
#  'Free space right',
#  'Lost',
#  'Not accurate',
#  'Accurate',
#  'Accurate',
#  'Right foot',
#  'High',
#  'Not accurate',
#  'Interception',
#  'Not accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Take on left',
#  'Lost',
#  'Not accurate',
#  'Take on right',
#  'Won',
#  'Accurate',
#  'Take on left',
#  'Lost',
#  'Not accurate',
#  'Not accurate',
#  'Interception',
#  'Accurate',
#  'Accurate',
#  'Not accurate',
#  'Interception',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Won',
#  'Accurate',
#  'Lost',
#  'Not accurate',
#  'High',
#  'Not accurate',
#  'Interception',
#  'Not accurate',
#  'Neutral',
#  'Accurate',
#  'Neutral',
#  'Accurate',
#  'Accurate',
#  'Not accurate',
#  'Interception',
#  'Interception',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Neutral',
#  'Accurate',
#  'Neutral',
#  'Accurate',
#  'Accurate',
#  'Lost',
#  'Not accurate',
#  'Won',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Not accurate',
#  'Interception',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Dangerous ball lost',
#  'Lost',
#  'Not accurate',
#  'Won',
#  'Accurate',
#  'Accurate',
#  'Lost',
#  'Not accurate',
#  'Accurate',
#  'Right foot',
#  'Not accurate',
#  'Interception',
#  'High',
#  'Accurate',
#  'Lost',
#  'Not accurate',
#  'Lost',
#  'Not accurate',
#  'Lost',
#  'Not accurate',
#  'Won',
#  'Accurate',
#  'Won',
#  'Accurate',
#  'Head/body',
#  'Opportunity',
#  'Position: Goal high right',
#  'Accurate',
#  'Position: Goal high right',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Not accurate',
#  'Interception',
#  'Accurate',
#  'Dangerous ball lost',
#  'Lost',
#  'Not accurate',
#  'Interception',
#  'Interception',
#  'Accurate',
#  'Accurate',
#  'Free space right',
#  'Lost',
#  'Not accurate',
#  'Free space right',
#  'Lost',
#  'Not accurate',
#  'Free space left',
#  'Won',
#  'Accurate',
#  'Left foot',
#  'Blocked',
#  'Not accurate',
#  'Interception',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Left foot',
#  'High',
#  'Accurate',
#  'Lost',
#  'Not accurate',
#  'Lost',
#  'Not accurate',
#  'Won',
#  'Accurate',
#  'Won',
#  'Accurate',
#  'Won',
#  'Accurate',
#  'Lost',
#  'Not accurate',
#  'Interception',
#  'Not accurate',
#  'Accurate',
#  'Lost',
#  'Not accurate',
#  'Won',
#  'Accurate',
#  'Accurate',
#  'Won',
#  'Accurate',
#  'Lost',
#  'Not accurate',
#  'Right foot',
#  'Direct',
#  'Opportunity',
#  'Position: Goal center',
#  'Accurate',
#  'Position: Goal center',
#  'Accurate',
#  'Not accurate',
#  'High',
#  'Accurate',
#  'Neutral',
#  'Accurate',
#  'Lost',
#  'Not accurate',
#  'Won',
#  'Accurate',
#  'Right foot',
#  'Position: Out high right',
#  'Not accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Take on right',
#  'Lost',
#  'Not accurate',
#  'Take on left',
#  'Won',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Lost',
#  'Not accurate',
#  'Won',
#  'Accurate',
#  'Won',
#  'Accurate',
#  'Lost',
#  'Not accurate',
#  'Accurate',
#  'Lost',
#  'Not accurate',
#  'Won',
#  'Accurate',
#  'Right foot',
#  'Blocked',
#  'Not accurate',
#  'Interception',
#  'Accurate',
#  'Not accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Lost',
#  'Not accurate',
#  'Won',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Left foot',
#  'Accurate',
#  'Interception',
#  'Lost',
#  'Not accurate',
#  'Won',
#  'Accurate',
#  'Not accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Right foot',
#  'Blocked',
#  'Not accurate',
#  'Interception',
#  'Not accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Right foot',
#  'High',
#  'Not accurate',
#  'Won',
#  'Accurate',
#  'Neutral',
#  'Accurate',
#  'Won',
#  'Accurate',
#  'Not accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Free space left',
#  'Lost',
#  'Not accurate',
#  'Free space right',
#  'Won',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Take on left',
#  'Lost',
#  'Not accurate',
#  'Take on right',
#  'Won',
#  'Accurate',
#  'Yellow card',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Through',
#  'Not accurate',
#  'Won',
#  'Accurate',
#  'Lost',
#  'Not accurate',
#  'Won',
#  'Accurate',
#  'Won',
#  'Accurate',
#  'Accurate',
#  'Free space right',
#  'Won',
#  'Accurate',
#  'Free space left',
#  'Lost',
#  'Not accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Neutral',
#  'Accurate',
#  'Neutral',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Right foot',
#  'High',
#  'Accurate',
#  'Lost',
#  'Not accurate',
#  'Won',
#  'Accurate',
#  'Not accurate',
#  'Right foot',
#  'Opportunity',
#  'Position: Out high right',
#  'Not accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Through',
#  'Not accurate',
#  'Interception',
#  'Accurate',
#  'Not accurate',
#  'Accurate',
#  'Accurate',
#  'Take on left',
#  'Lost',
#  'Not accurate',
#  'Take on right',
#  'Won',
#  'Accurate',
#  'Not accurate',
#  'Interception',
#  'Accurate',
#  'Not accurate',
#  'Accurate',
#  'Accurate',
#  'Neutral',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Lost',
#  'Not accurate',
#  'Won',
#  'Accurate',
#  'Accurate',
#  'Through',
#  'Not accurate',
#  'Interception',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Not accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Sliding tackle',
#  'Won',
#  'Accurate',
#  'Lost',
#  'Not accurate',
#  'Accurate',
#  'Accurate',
#  'Neutral',
#  'Accurate',
#  'Neutral',
#  'Accurate',
#  'Not accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Free space right',
#  'Won',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Right foot',
#  'Accurate',
#  'Accurate',
#  'Free space left',
#  'Won',
#  'Accurate',
#  'Free space right',
#  'Lost',
#  'Not accurate',
#  'Left foot',
#  'Not accurate',
#  'Interception',
#  'Not accurate',
#  'High',
#  'Not accurate',
#  'Interception',
#  'Not accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Not accurate',
#  'Interception',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Right foot',
#  'High',
#  'Not accurate',
#  'Not accurate',
#  'Accurate',
#  'Not accurate',
#  'Interception',
#  'Accurate',
#  'Missed ball',
#  'Accurate',
#  'Not accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Through',
#  'Not accurate',
#  'Interception',
#  'Not accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Left foot',
#  'Blocked',
#  'Not accurate',
#  'Interception',
#  'Accurate',
#  'Lost',
#  'Not accurate',
#  'Won',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Won',
#  'Accurate',
#  'Lost',
#  'Not accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Right foot',
#  'Blocked',
#  'Not accurate',
#  'Interception',
#  'Accurate',
#  'Accurate',
#  'Not accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Right foot',
#  'Not accurate',
#  'Interception',
#  'Not accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Lost',
#  'Not accurate',
#  'Won',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Free space right',
#  'Lost',
#  'Not accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Not accurate',
#  'Interception',
#  'Not accurate',
#  'Interception',
#  'Accurate',
#  'Right foot',
#  'High',
#  'Not accurate',
#  'Accurate',
#  'Anticipated',
#  'Neutral',
#  'Accurate',
#  'Anticipation',
#  'Neutral',
#  'Accurate',
#  'Lost',
#  'Not accurate',
#  'Not accurate',
#  'Accurate',
#  'Neutral',
#  'Accurate',
#  'Neutral',
#  'Accurate',
#  'Accurate',
#  'Neutral',
#  'Accurate',
#  'Neutral',
#  'Accurate',
#  'Won',
#  'Accurate',
#  'Lost',
#  'Not accurate',
#  'Accurate',
#  'Accurate',
#  'Lost',
#  'Not accurate',
#  'Not accurate',
#  'Take on left',
#  'Won',
#  'Accurate',
#  'Accurate',
#  'Not accurate',
#  'Accurate',
#  'Accurate',
#  'Sliding tackle',
#  'Neutral',
#  'Accurate',
#  'Won',
#  'Accurate',
#  'Sliding tackle',
#  'Lost',
#  'Not accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Not accurate',
#  'Interception',
#  'Neutral',
#  'Accurate',
#  'Neutral',
#  'Accurate',
#  'Neutral',
#  'Accurate',
#  'Neutral',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Won',
#  'Accurate',
#  'Not accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Free space right',
#  'Won',
#  'Accurate',
#  'Right foot',
#  'Blocked',
#  'Opportunity',
#  'Not accurate',
#  'Interception',
#  'High',
#  'Accurate',
#  'Lost',
#  'Not accurate',
#  'Won',
#  'Accurate',
#  'Left foot',
#  'Accurate',
#  'Lost',
#  'Not accurate',
#  'Won',
#  'Accurate',
#  'Take on left',
#  'Lost',
#  'Not accurate',
#  'Take on right',
#  'Won',
#  'Accurate',
#  'Right foot',
#  'Opportunity',
#  'Position: Goal low center',
#  'Accurate',
#  'Position: Goal low center',
#  'Accurate',
#  'Accurate',
#  'Lost',
#  'Not accurate',
#  'Won',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Through',
#  'Accurate',
#  'Lost',
#  'Not accurate',
#  'Sliding tackle',
#  'Won',
#  'Accurate',
#  'Not accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Not accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Won',
#  'Accurate',
#  'Sliding tackle',
#  'Lost',
#  'Not accurate',
#  'Accurate',
#  'Won',
#  'Accurate',
#  'Lost',
#  'Not accurate',
#  'Accurate',
#  'Not accurate',
#  'Interception',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Not accurate',
#  'Interception',
#  'Not accurate',
#  'Not accurate',
#  'Accurate',
#  'Not accurate',
#  'Interception',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Neutral',
#  'Accurate',
#  'Accurate',
#  'Free space right',
#  'Anticipation',
#  'Won',
#  'Accurate',
#  'Free space left',
#  'Anticipated',
#  'Lost',
#  'Not accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Free space left',
#  'Neutral',
#  'Accurate',
#  'Free space right',
#  'Neutral',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  'Accurate',
#  ...]

# %%
set(match_events['tags'].sum())
# Out:
# {134387,
#  146583,
#  14731,
#  14732,
#  15781,
#  18669,
#  209567,
#  3318,
#  349687,
#  51625,
#  'Accurate',
#  'Anticipated',
#  'Anticipation',
#  'Assist',
#  'Blocked',
#  'Counter attack',
#  'Dangerous ball lost',
#  'Direct',
#  'Fairplay',
#  'Free space left',
#  'Free space right',
#  'Goal',
#  'Head/body',
#  'High',
#  'Interception',
#  'Key pass',
#  'Left foot',
#  'Lost',
#  'Missed ball',
#  'Neutral',
#  'Not accurate',
#  'Opportunity',
#  'Position: Goal center',
#  'Position: Goal center left',
#  'Position: Goal center right',
#  'Position: Goal high center',
#  'Position: Goal high right',
#  'Position: Goal low center',
#  'Position: Goal low left',
#  'Position: Out center left',
#  'Position: Out high left',
#  'Position: Out high right',
#  'Position: Out low left',
#  'Right foot',
#  'Sliding tackle',
#  'Take on left',
#  'Take on right',
#  'Through',
#  'Won',
#  'Yellow card'}

# %%
match_events[match_events['event_type'] == 'Substitution']
# Out:
#      match_id event_id period    time team_id       team_name player_id  \
# 977   2057988        0     2H   600.0   14855  Korea Republic    349687
# 978   2057988        0     2H   600.0   14855  Korea Republic     15781
# 1001  2057988        0     2H   720.0    3148         Germany     14731
# 1002  2057988        0     2H   720.0    3148         Germany      3318
# 1086  2057988        0     2H  1020.0    3148         Germany     14732
# 1087  2057988        0     2H  1020.0    3148         Germany    134387
# 1207  2057988        0     2H  1380.0   14855  Korea Republic    209567
# 1208  2057988        0     2H  1380.0   14855  Korea Republic     51625
# 1361  2057988        0     2H  1920.0    3148         Germany    146583
# 1362  2057988        0     2H  1920.0    3148         Germany     18669
#
#          player_name    event_type sub_event_type      tags  start_x  start_y  \
# 977   Hwang Hee-Chan  Substitution      Player in   [15781]      NaN      NaN
# 978     Ja-Cheol Koo  Substitution     Player out  [349687]      NaN      NaN
# 1001        M. Gómez  Substitution      Player in    [3318]      NaN      NaN
# 1002      S. Khedira  Substitution     Player out   [14731]      NaN      NaN
# 1086       T. Müller  Substitution      Player in  [134387]      NaN      NaN
# 1087     L. Goretzka  Substitution     Player out   [14732]      NaN      NaN
# 1207      Se-Jong Ju  Substitution      Player in   [51625]      NaN      NaN
# 1208   Seon-Min Moon  Substitution     Player out  [209567]      NaN      NaN
# 1361       J. Brandt  Substitution      Player in   [18669]      NaN      NaN
# 1362       J. Hector  Substitution     Player out  [146583]      NaN      NaN
#
#       end_x  end_y
# 977     NaN    NaN
# 978     NaN    NaN
# 1001    NaN    NaN
# 1002    NaN    NaN
# 1086    NaN    NaN
# 1087    NaN    NaN
# 1207    NaN    NaN
# 1208    NaN    NaN
# 1361    NaN    NaN
# 1362    NaN    NaN
